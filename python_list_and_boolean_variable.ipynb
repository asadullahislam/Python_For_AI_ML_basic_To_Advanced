# %%
str="hello world"

# %%
str.isalnum()
# Out:
# False

# %%
my_str="Joy123"
my_str.isalnum()
# Out:
# True

# %%
my_str.istitle()
# Out:
# True

# %% [markdown]
# ### Boolean & logical operation

# %%
example ='hello world'
my_str= "joy"

# %%
my_str.isalpha() or example.isnum()
# Out:
# True

# %% [markdown]
# ### list

# %%
list1 =[1,2,3 ,4,5 ]

# %%
list2= list1.copy()

# %%
list1
# Out:
# [1, 2, 3, 4, 5]

# %%
list2
# Out:
# [1, 2, 3, 4, 5]

# %%
# list2.append(8)
list2
# Out:
# [1, 2, 3, 4, 5, 8]

# %%
lst2[:5]
# Out:
# [1, 2, 3, 4, 5]

# %%
list2[1:6]
# Out:
# [2, 3, 4, 5, 8]

# %%
# list2.insert(2, 99)

# %%
list2
# Out:
# [1, 2, 99, 99, 3, 4, 5, 8]

# %%
#extend
list2.extend([19,20,21])

# %%
list2
# Out:
# [1, 2, 99, 99, 3, 4, 5, 8, 19, 20, 21]

# %%
sum(list2)
# Out:
# 281

# %%
list2.pop()
# Out:
# 21

# %%
list2
# Out:
# [1, 2, 99, 99, 3, 4, 5, 8, 19, 20]

# %%
list2.remove(20)

# %%
list2
# Out:
# [1, 2, 99, 99, 3, 4, 5, 8, 19]

# %%
list2.count(99)
# Out:
# 2

# %%
list2.index(3,2,99)
# Out:
# 4

# %% [markdown]
# ### Dictionary

# %%
my_dict={'car1':"BMw",'car2':"audi",'car3':'marcedez benz'}

# %%
my_dict['car1']
# Out:
# 'BMw'

# %%
for x in my_dict:
    print(x)
# Out:
# car1
# car2
# car3

# %%
for x in my_dict.values():
    print(x)
# Out:
# BMw
# audi
# marcedez benz

# %%
for x in my_dict.items():
    print(x)
# Out:
# ('car1', 'BMw')
# ('car2', 'audi')
# ('car3', 'marcedez benz')

# %%
my_dict['cars1']='honda'

# %%
my_dict
# Out:
# {'car1': 'BMw', 'car2': 'audi', 'car3': 'marcedez benz', 'cars1': 'honda'}

# %%
### Nested Dictionary
car1_model={'car1':"BMw"}
car2_model={'car2':"HONDA"}
car3_model={'car3':"AUDI"}

# %%
car_type={'car1':car1_model,'car2':car2_model,'car3':car3_model}

# %%
car_type
# Out:
# {'car1': {'car1': 'BMw'}, 'car2': {'car2': 'HONDA'}, 'car3': {'car3': 'AUDI'}}

# %%
car_type["car1"]
# Out:
# {'car1': 'BMw'}

# %%
car_type["car1"]["car1"]
# Out:
# 'BMw'
