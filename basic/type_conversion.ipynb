# %% [markdown]
# ### type conversion

# %%
# 1.type conversion
#2. Type casting

# %%
ans= 5+ 10.0
print(type(ans))
# Out:
# <class 'float'>

# %%
ans1=int(ans)
print(type(ans1))
# Out:
# <class 'int'>

# %%
val= int("123")
type(val)
val1= bool(10)
type(val1)
# Out:
# bool
