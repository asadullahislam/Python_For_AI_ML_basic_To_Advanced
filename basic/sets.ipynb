# %% [markdown]
# # ipynb

# %% [markdown]
# #sets , collection of unique element  # immuteable

# %%
s={1,2,2,2,3}
print(s)
# Out:
# {1, 2, 3}

# %%
s={1,2,2,2,3}
print(type(s))
print(len(s))
# Out:
# <class 'set'>
# 3

# %%
# set method 
s.add(5)
print(s)
# Out:
# {1, 2, 3, 5}

# %%
# this is a dictionary 
empty_set={}
print(type(empty_set))
# Out:
# <class 'dict'>

# %%
# for empty set create 
empty_set=set()
print(type(empty_set))
# Out:
# <class 'set'>

# %% [markdown]
# # Set method

# %%
s={1,2,2,2,3}
#add method 
s.add(5)
print(s)
# Out:
# {1, 2, 3, 5}

# %%
#remove 
s.remove(1)
print(s)
# Out:
# {2, 3, 5}

# %%
#clear
s.clear()
print(s)
# Out:
# set()

# %%
#pop is remove a random variable  
s={1,2,2,2,3}
print(s)
s.pop()
print(s)
# Out:
# {1, 2, 3}
# {2, 3}

# %%
#union , intersection 
s1={1,2,3,4,5}
s2={4,5,6,7,8,9}
print(s1.union(s2))
print(s1.intersection(s2))
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}
# {4, 5}
