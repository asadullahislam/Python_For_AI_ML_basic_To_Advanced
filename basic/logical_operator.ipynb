# %% [markdown]
# Logical Operator

# %%
x=10; y=5; z=3
result =(x>y) and (x>z)
print(result)
# Out:
# True

# %%
result=(x>y) or (x>z)
print(result)
# Out:
# True

# %%
result=(y>x) and (x>z)
print(result)
# Out:
# False

# %% [markdown]
# ## Precedence and Associativity

# %%
which operation fast based on ther precidence  like (),* ,/, +,-
