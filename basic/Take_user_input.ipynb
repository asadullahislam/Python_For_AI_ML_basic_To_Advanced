# %% [markdown]
# ### take user input

# %%
a=input("Enter valu of a:")
print(a)
# Out:
# 5

# %%
 a=int(input("Enter a:"))
 b= int(input("Enter b:"))
 sum= a+b
 print(a,b)
 print("sum of a+b :",sum)
# Out:
# 5 10
# sum of a+b : 15
