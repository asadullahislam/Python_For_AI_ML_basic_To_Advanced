# %%
row_number =input()
print(row_number)
type(row_number)
# Out:
# 10 20 30
# str

# %%
row_number = input()
numbers=row_number.split()
print(numbers)
print(type(numbers))
# Out:
# ['10', '20', '30']
# <class 'list'>

# %%
row_number = input()
numbers=row_number.split()
num1=int(numbers[0])
num2=int(numbers[1])
print(numbers)
print(type(numbers))
print(num1,num2)
print(num1+num2)
# Out:
# ['10', '20']
# <class 'list'>
# 10 20
# 30

# %% [markdown]
# ### conditional statement
